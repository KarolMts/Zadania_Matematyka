# %% [markdown]
# Wystarczy $k = 2027$
#
# i wtedy
# dla  $p = 2$ mamy:
#
# $p^2  + k = 4 + 2027 = 2031 = 3*667$,
#
# natomiast gdy $p$ jest liczbą pierwszą nieparzystą to liczba $p^2 + k$ będzie parzysta jako suma dwóch liczb nieparzystych.

# %% [markdown]
# A zatem $p^2 + k $ jest złożona dla kaźdej l. pierwszej $p$ przy $k = 2027$
